# %% [markdown]
# # Instagram Pulls
#
# In this notebook we will use the instagram scraper class to collect any information from instagram that might be useful for us.

# %%
import instagram_scraper 

# # for dev
# from importlib import reload
# instagram_scraper = reload(instagram_scraper)

# %% [markdown]
# ## Useful Hashtags
#
# We can use the `get_related_hashtag_volume` method to get hashtags related to given base words or hashtags that we're interested in. This method returns the suggested search results from inputing text to the instagram search bar.

# %%
# instantiate the class 
scraper = instagram_scraper.instagram_scraper() 

# define the hashtags you 
hashtags = ['sunset',                                  
            'sky',
            'rainbow',
            'sandiego',
            'california',
            'pacific',
            'cloud',
            'hidef',
            'pixel']

data = scraper.get_related_hashtag_volume(hashtags)
data = data.drop_duplicates(subset='hashtags')
data = data.sort_values('posts', ascending=False)
# Out:
#                      hashtags    posts
# 287          pacificnorthwest  3723438
# 19             sunset_madness  3323069
# 464                pixel_kids  3084658
# 465                  pixel_ig  2776855
# 356                cloudscape  2735928
# 275                   pacific  2689243
# 476              mypixeldiary  2650685
# 367              cloudchasing  2526171
# 285              pacificocean  2483059
# 228       californiaadventure  2467292
# 99               sky_captures  2415286
# 14                    sunset🌅  2343448
# 229            californialove  2256807
# 113                  rainbows  2153666
# 20              sunset_vision  2144999
# 361                 cloudyday  2005204
# 133           rainbowsixsiege  1974799
# 440                     pixel  1915549
# 91             sky_perfection  1832486
# 34                sunsetlover  1810938
# 96                   skylover  1789559
# 68                  skydiving  1785696
# 460                  pixelart  1666245
# 486                 teampixel  1657884
# 8                  sunset_hub  1637571
# 370              cloudstagram  1618832
# 73                     skyrim  1584486
# 56             sky_brilliance  1561711
# 239        californiadreaming  1556963
# 88                sky_sultans  1533531
# ..                        ...      ...
# 420               hidefitclub      381
# 409                hidefyouth      378
# 400                  hidefink      365
# 389                 hidefcraw      345
# 421  hidefinitionprofessional      290
# 416             hidefcarolina      282
# 431    hidefinitionbarbershop      264
# 426         hidefinitionbrows      246
# 405                 hidefvape      245
# 430               hidefrommom      242
# 410        hidefliposculpture      242
# 393          hidefliposuction      240
# 434                    hideff      225
# 422            hidefbeautybar      219
# 406                  hidefood      213
# 435                    hidefy      211
# 407                hidefmusic      204
# 412           hidefarmkitchen      192
# 423                hidefbrows      191
# 436          hidefperformance      181
# 401             hidefromhelix      180
# 437             hidefeelings✨      174
# 388               hidefacedps      168
# 428             hidefgraphics      160
# 402               hidefnights      156
# 429             hidefromhubby      150
# 439          hidefumiwatanabe      139
# 417                 hideflive      123
# 438           hideflametattoo      122
# 432                  hidefnes      121
#
# [474 rows x 2 columns]

# %% [markdown]
# ### *Copy & Paste Hashtags for Your Post*
#
# We can print out the hashtags so you can copy and paste them into your posts. Below we are only keeping hastags that have over a million posts. And since ***Instagram only lets you post a maximum of 30 hashtags*** we limit the print out to 30.

# %%
'#'+' #'.join(data[data['posts']>1000000]['hashtags'].values[:30])
# Out:
# '#sunset #sky #clouds #california #rainbow #skyporn #sandiego #cloudporn #skyline #cloud #skylovers #sunsets #cloudy #skyscraper #sunsetlovers #sunset_pics #cloudchaser #skypainters #nightsky #sunsetporn #pacificnorthwest #sunset_madness #pixel_kids #pixel_ig #cloudscape #pacific #mypixeldiary #cloudchasing #pacificocean #californiaadventure'
