# %% [markdown]
# # Instagram Pulls
#
# In this notebook we will use the instagram scraper class to collect any information from instagram that might be useful for us.

# %%
import instagram_scraper 

# # for dev
# from importlib import reload
# instagram_scraper = reload(instagram_scraper)

# %% [markdown]
# ## Useful Hashtags
#
# We can use the `get_related_hashtag_volume` method to get hashtags related to given base words or hashtags that we're interested in. This method returns the suggested search results from inputing text to the instagram search bar.

# %%
data
# Out:
#                        hashtags     posts
# 102                      hiphop  70104802
# 0                           rap  42300293
# 516                      poetry  33191464
# 15                   rapmonster  17140723
# 16                       rapper  14516311
# 147                     hipster  13919369
# 399                        poem  13790811
# 299                      lyrics  11155220
# 709                    feelings  10447144
# 499                        poet  10341544
# 123                      hippie  10313598
# 582             poetrycommunity   9272560
# 597            poetsofinstagram   8746627
# 408                       poems   8358224
# 727                    feelgood   8266369
# 714                     feeling   8212377
# 699                        feel   5639624
# 157                 hiphopmusic   5392747
# 735                 feelinggood   5238283
# 60                      rappers   4656623
# 592                   poetsofig   4366604
# ...

# %% [markdown]
# ### *Copy & Paste Hashtags for Your Post*
#
# We can print out the hashtags so you can copy and paste them into your posts. Below we are only keeping hastags that have over a million posts. And since ***Instagram only lets you post a maximum of 30 hashtags*** we limit the print out to 30.

# %%
'#'+' #'.join(data[data['posts']>1000000]['hashtags'].values[:50])
# Out:
# '#hiphop #rap #poetry #rapmonster #rapper #hipster #poem #lyrics #feelings #poet #hippie #poetrycommunity #poetsofinstagram #poems #feelgood #feeling #feel #hiphopmusic #feelinggood #rappers #poetsofig #feels #rapmusic #hiphopculture #poetryisnotdead #rapmon #worldstarhiphop #feelingmyself #poets #fridayfeeling #kendricklamar #rapunzel #hiphophead #hippy #undergroundhiphop #poema #poemas #feelingood #hippiestyle #hiphopdance #hip #hiphopartist #hipertrofia #raptors #poemsofinstagram #instapoem #poeta #raptor #poetic #feelthebern'
